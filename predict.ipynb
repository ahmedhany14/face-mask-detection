# %%
# %cd "/home/hany_jr/Ai/Data sets/Face mask/archive/results"
# Out:
# /home/hany_jr/Ai/Data sets/Face mask/archive/results

# %%
# !yolo predict model='/home/hany_jr/Ai/Data sets/Face mask/archive/results/runs/detect/train/weights/best.pt' source = "/home/hany_jr/Ai/Data sets/Face mask/archive/test/images"
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.12.4 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 7932MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/171 /home/hany_jr/Ai/Data sets/Face mask/archive/test/images/maksssksksss102.png: 384x640 2 with_masks, 23.8ms
# image 2/171 /home/hany_jr/Ai/Data sets/Face mask/archive/test/images/maksssksksss103.png: 480x640 5 with_masks, 23.5ms
# image 3/171 /home/hany_jr/Ai/Data sets/Face mask/archive/test/images/maksssksksss123.png: 512x640 1 with_mask, 23.8ms
# image 4/171 /home/hany_jr/Ai/Data sets/Face mask/archive/test/images/maksssksksss125.png: 640x512 1 without_mask, 23.4ms
# image 5/171 /home/hany_jr/Ai/Data sets/Face mask/archive/test/images/maksssksksss126.png: 640x448 1 without_mask, 2 with_masks, 23.3ms
# image 6/171 /home/hany_jr/Ai/Data sets/Face mask/archive/test/images/maksssksksss128.png: 640x512 1 without_mask, 3.2ms
# ...
