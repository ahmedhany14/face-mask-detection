# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.12.4 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 7932MiB)
# Setup complete ✅ (12 CPUs, 15.4 GB RAM, 98.4/422.9 GB disk)

# %%
# %cd "/home/hany_jr/Ai/Data sets/Face mask/archive/results"
# Out:
# /home/hany_jr/Ai/Data sets/Face mask/archive/results

# %%
# !yolo train model=yolov8n.pt data = "/home/hany_jr/Ai/face-mask-detection/data.yaml" epochs=100 imgsz=640
# Out:
# ...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:03<00:00, 2.11MB/s]
# New https://pypi.org/project/ultralytics/8.2.83 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.82 🚀 Python-3.12.4 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 7932MiB)
# ...
